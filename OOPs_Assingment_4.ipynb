# %% [markdown]
# ## OOPS Assingment

# %% [markdown]
# #Theory

# %% [markdown]
# Q. 1 What is Object-Oriented Programming (OOP) ?
# - OOP is a way of writing programs by creating objects that contain both data and Code .

# %% [markdown]
# Q.2  What is a class in OOP ?
# - Class is a blueprint or templets in OOP.

# %% [markdown]
# Q.3  What is an object in OOP ?
# - An object in OPP is a real instance

# %% [markdown]
# Q.4 What is the difference between abstraction and encapsulation ?
# - Abstraction shows what a system does, while encapsulation protects how the data is handled.

# %% [markdown]
# Q.5 What are dunder methods in Python ?
# - Dunder methods are special Python methods with double underscores that define how objects behave, like __init__, __str__, and __add__ Also known as magic method.

# %% [markdown]
# Q.6 Explain the concept of inheritance in OOP ?
# -  Inheritance is  an OOPS concept where one class is parent class and another is child, and parent class allow to use properties and method to reuse child class.

# %% [markdown]
# Q. 7 What is polymorphism in OOP ?
# - Polymorphism is like one interface and multiple implementation or like same method but behave diffrent in diffrent object.

# %% [markdown]
# Q. 8 How is encapsulation achieved in Python ?
# - Data is hiding through access modifiers and only acess who know class and its structure and thats the way to achieve encapsulation in python.

# %% [markdown]
# Q. 9 What is a constructor in Python ?
# -  A constructor in Python is a special method (__init__) that automatically runs when an object is created to initialize its data.

# %% [markdown]
# Q.10 What are class and static method in python ?
# - A class method works with the class itself using @classmethod, while a static method is a utility function inside a class using @staticmethod and does not access class or instance data.

# %% [markdown]
# Q. 11 What is method overloading in python ?
# - Method overloading in Python means defineing multiple parameter but method is same, with same name. Python does not support it. Python give an error.

# %% [markdown]
# Q. 12 What is method overriding in OOP ?
# -  In python, method overringg ahh in OPP is the process of providing  a diffrent implementation for a method is already defined in superclass or in subclass.

# %% [markdown]
# Q.13 What is a property decorator in Python ?
# -  Property decorator (@property) in Python allows you to access a method like an attribute while adding control over class data.

# %% [markdown]
# Q.14  Why is polymorphism important in OOP ?
# - Polymorphism is important in OOP because it allows the same interface to work with different object types, making code more flexible, reusable, and easier to maintain.

# %% [markdown]
# Q. 15 What is an abstract class in Python ?
# - An abstract class in Python is a class that cannot be instantiated and is used to define a blueprint with abstract methods that must be implemented by child classes.

# %% [markdown]
# Q.16 What are the advantages of OOP ?
# - Advantages of OOP include code reusability, better organization, easier maintenance, scalability, data security, and improved problem-solving through real-world modeling.

# %% [markdown]
# Q. 17 What is the difference between a class variable and an instance variable ?
# - A class variable is shared by all objects of a class, while an instance variable is unique to each object.

# %% [markdown]
# Q.18 What is multiple inheritance in Python ?
# -  Multiple inheritance in Python is a situation where a class can inherit attributes and methods from more than one parent class.

# %% [markdown]
# Q.19 Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python ?
# - __str__ returns a user-friendly string representation of an object, while __repr__ returns an unambiguous, developer-oriented representation mainly for debugging.

# %% [markdown]
# Q.20 What is the significance of the ‘super()’ function in Python ?
# - The super() function is used to call methods of a parent (base) class.

# %% [markdown]
# Q.21 What is the significance of the __del__ method in Python ?
# - The __del__ method is a delete in Python that is called when an object is about to be destroyed, allowing cleanup of resources.

# %% [markdown]
# Q. 22 What is the difference between @staticmethod and @classmethod in Python ?
# - @staticmethod does not access class or instance data, while @classmethod works with the class itself using cls.

# %% [markdown]
# Q.23 How does polymorphism work in Python with inheritance ?
# -  In Python, polymorphism with inheritance works through method overriding, where a child class provides its own implementation of a parent class method, and the correct method is called at runtime based on the object type.

# %% [markdown]
# Q.24 What is method chaining in Python OOP ?
# - Method chaining in Python OOP is a technique where multiple methods are called on the same object in a single line by returning self from each method.

# %% [markdown]
# Q.25 What is the purpose of the __call__ method in Python?
# - The __call__ method allows an object to be called like a function, enabling function-like behavior for class instances.

# %% [markdown]
# ## Practical Question

# %% [markdown]
# Q 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

# %%
# Parent class
class Animal:
    def speak(self):
        print("Generic animal sound")

# Child class
class Dog(Animal):
    def speak(self):
        print("Bark!")

a = Animal()
a.speak()

d = Dog()
d.speak()
# Out:
# Generic animal sound
# Bark!

# %% [markdown]
# Q . 2. Write a program to create an abstract class Shape with a method area().Derive classes Circle and Rectangle from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod

class Shape:
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return 3.14 * self.radius ** 2


class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height
    def area(self):
        return self.width * self.height


c = Circle(3)
print(c.area())

r = Rectangle(3, 15)
print(r.area())
# Out:
# 28.26
# 45

# %% [markdown]
# Q. 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
    def __init__(self, type):
      self.type = type

class Car(Vehicle):
    def __init__(self, type):
        super().__init__(type)

class ElectricCar(Car):
    def __init__(self, type, battery):
        super().__init__(type)
        self.battery = battery

mycar = ElectricCar("tesls0","full")
print(mycar.type)
print(mycar.battery)

mycar2 = Car("audi")
print(mycar2.type)
# Out:
# tesls0
# full
# audi

# %% [markdown]
# Q 4. Demonstrate polymorphism by creating a base class Bird with a method fl(). Create two derived classes Sparrow and Penguin that override the fly() method

# %%
class Bird:
  def fly(self):
    print("Birds can fly")

class Sparrow(Bird):
  def fly(self):
    print("Sparrows can fly")

class Penguin(Bird):
  def fly(self):
    print("Penguins can't fly")

bird = Bird()
bird.fly()

sparrow = Sparrow()
sparrow.fly()

penguin = Penguin()
penguin.fly()
# Out:
# Birds can fly
# Sparrows can fly
# Penguins can't fly

# %% [markdown]
# Q 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance

# %%
class BankAccount:
  def __init__(self,name):
     self.name = name
     self.__balance = 0

  def deposit(self,amount):
    self.__balance += amount

  def withdraw(self,amount):
    if self.__balance >= amount:
      self.__balance -= amount

  def balance(self):
    print(self.__balance)

ajay = BankAccount("Ajay")
ajay.deposit(1000)
ajay.withdraw(500)
ajay.balance()
# Out:
# 500

# %% [markdown]
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

# %%
class Instrument:
  def play(self):
    pass

class Guitar(Instrument):
  def play(self):
    print("Guitar is playing")

class Piano(Instrument):
  def play(self):
    print("Piano is playing")

guitar = Guitar()
guitar.play()

piano = Piano()
piano.play()
# Out:
# Guitar is playing
# Piano is playing

# %% [markdown]
# Q 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
  @classmethod
  def add_numbers(cls, a, b):
    return a + b

  @staticmethod
  def subtract_numbers(a, b):
    return a - b

x = MathOperations()
print(x.add_numbers(50, 50))
print(x.subtract_numbers(100, 50))
# Out:
# 100
# 50

# %% [markdown]
# Q 8. Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
  count = 0
  def __init__(self, name):
    self.name = name
    Person.count += 1

  @classmethod
  def count_persons(cls):
    return cls.count

person1 = Person("Ajay")
person2 = Person("Sanjay")
person3 = Person("Vijay")

count = Person.count_persons()
print(count)
# Out:
# 3

# %% [markdown]
# Q. 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

# %%
class Fraction:
  def __init__(self, numerator, denominator):
    self.numerator = numerator
    self.denominator = denominator

class Fraction2(Fraction): #we can also do this with same classs but this done with inheritance class for practice
  def __str__(self):
    return f"{self.numerator}/{self.denominator}"

f = Fraction2(10,20)
print(f)
# Out:
# 10/20

# %% [markdown]
# Q. 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(4, 5)

v3 = v1 + v2

print(v3)
# Out:
# (6, 8)

# %% [markdown]
# Q. 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def greet(self):
    print(f"Hello, my name is {self.name} and I am {self.age} years old.")

person1 = Person("Ajay", 28)
person1.greet()
# Out:
# Hello, my name is Ajay and I am 28 years old.

# %% [markdown]
# Q. 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades

# %%
class Student:
  def __init__(self, name, grades):
    self.name = name
    self.grades = grades

  def average_grade(self):
    return sum(self.grades)/len(self.grades)

student12 = Student("AJAY", [10,20,30,40])
print(student12.average_grade())
# Out:
# 25.0

# %% [markdown]
# Q. 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

# %%
class Rectangle:
  def __init__(self, length, width):
    self.length = 0
    self.width = 0


  def set_dimensions(self, length, width):
      self.length = length
      self.width = width

  def area(self):
      return self.length * self.width

q13 = Rectangle(10,20)
print(q13.area())

q13 = Rectangle(0,0) # set dimesions
q13.set_dimensions(10,20)
print(q13.area())
# Out:
# 0
# 200

# %% [markdown]
# Q 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary

# %%
class Employee:
  def __init__(self, name, hours_worked, hourly_rate):
    self.name = name
    self.hours_worked = hours_worked
    self.hourly_rate = hourly_rate

  def calculate_salary(self):
    return self.hours_worked * self.hourly_rate

class Manager(Employee):
  def __init__(self, name, hours_worked, hourly_rate, bonus):
    super().__init__(name, hours_worked, hourly_rate)
    self.bonus = bonus

  def calculate_salary(self):
     return super().calculate_salary() + self.bonus

emp1 = Employee("Rahul", 40, 200)
print("Employee Salary:", emp1.calculate_salary())

mgr1 = Manager("Sonia", 40, 200, 5000)
print("Manager Salary:", mgr1.calculate_salary())
# Out:
# Employee Salary: 8000
# Manager Salary: 13000

# %% [markdown]
# Q 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

# %%
class Product:
  def __init__(self, name, price, quantity):
    self.name = name
    self.price = price
    self.quantity = quantity

  def total_price(self):
    return self.price * self.quantity

product15 = Product("Apple", 100, 5)
print(product15.total_price())
# Out:
# 500

# %% [markdown]
# Q 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

# %%
from abc import ABC, abstractmethod
class Animal:
  @abstractmethod
  def sound(self):
    pass

class Cow(Animal):
  def sound(self):
    return ("Moooow")

class Sheep(Animal):
  def sound(self):
    return ("Baeeee")


c = Cow()
print("cow speak like this" ,c.sound())

s = Sheep()
print("sheep speak like this",s.sound())
# Out:
# cow speak like this Moooow
# sheep speak like this Baeeee

# %% [markdown]
# Q 17. Create a class Book with attributes title, author, and year_published.Add a method get_book_info() that returns a formatted string with the book's details.

# %%
class Book:
  def __init__(self, title, author, year):
    self.title = title
    self.author = author
    self.year = year

  def get_book_info(self):
    return f"Title: {self.title}, Author: {self.author}, Year: {self.year}"

  def __str__(self): #i dont understand clear quertion so both method here
    return f"Title: {self.title}, Author: {self.author}, Year: {self.year}"

book17 = Book("Atrapi", "Dhruv Bhatt", 1997)

print(book17.get_book_info())

print(book17)
# Out:
# Title: Atrapi, Author: Dhruv Bhatt, Year: 1997
# Title: Atrapi, Author: Dhruv Bhatt, Year: 1997

# %% [markdown]
# Q 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

# %%
class House:
  def __init__(self, address, price):
    self.address = address
    self.price = price
  def __str__(self):
    return f"Address: {self.address}, Price: {self.price}"

class Mansion(House):
  def __init__(self, address, price, number_of_rooms):
    super().__init__(address, price)
    self.number_of_rooms = number_of_rooms

  def __str__(self):
    return f"{super().__str__()}, Number of rooms: {self.number_of_rooms}"

last = Mansion("Rajkot",10000,5)
print(last)

new = House("Rajkot",10000)
print(new)

Mansion3 = Mansion("Rajkot",10000,5)
print(Mansion3)
# Out:
# Address: Rajkot, Price: 10000, Number of rooms: 5
# Address: Rajkot, Price: 10000
# Address: Rajkot, Price: 10000, Number of rooms: 5
